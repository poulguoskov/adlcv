# %% [markdown]
# Complete the implementation of the masked attention module in gpt.py
#
# Then, test your implementation with test_implementation.py:

# %%
# !python3 test_implementation.py

# %% [markdown]
# Train your model (it will take ~15 minutes with a free T4 Google Colab GPU):

# %%
# !python3 train.py

# %% [markdown]
# Implement the autoregressive generation function generate_text in test.py.
#           Start with a simple greedy strategy. Choose the next token as the token with the highest probability.

# %%
# !python3 test.py

# %% [markdown]
# Now, implement multinomial sampling to generate more diverse outputs. In order to convert logits to a probability distribution, use a softmax layer with temperature. Comment on the effect of the temperature. Compare the results with the greedy strategy.

# %%
# !python3 test.py
